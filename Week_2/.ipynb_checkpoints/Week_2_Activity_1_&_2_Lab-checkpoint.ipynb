# %% [markdown]
# ## Activity 1 (Monday)
#
# - Aggregate the data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.
# - Standardizing header names
# - Removing duplicates
# - Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
# - Clean the number of open complaints and extract the middle number which is changing between records.
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns

# %%
import numpy as np
import pandas as pd

# %%
 #loading all 3 files
file1_df = pd.read_csv('file1.csv')
file2_df = pd.read_csv('file2.csv')
file3_df = pd.read_csv('file3.csv')

# %%
#checking how file1 looks like
file1_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#checking general info of file 1. Note: Cutomer Lifetime and Number of Open Complaints are objects
file1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
#checking the NaNs in Customer Lifetime Value for file1
file1_df['Customer Lifetime Value'].isna().sum()
# Out:
# 2940

# %%
#counting how many '%' are in the colum Custome Lifetime Values
count_percent1 = file1_df['Customer Lifetime Value'].str.contains('%').sum()
count_percent1
# Out:
# 1068

# %%
#Checking how file 2 looks like
file2_df
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   996 non-null    object
#  1   ST                         996 non-null    object
#  2   GENDER                     991 non-null    object
#  3   Education                  996 non-null    object
#  4   Customer Lifetime Value    992 non-null    object
#  5   Income                     996 non-null    int64
#  6   Monthly Premium Auto       996 non-null    int64
#  7   Number of Open Complaints  996 non-null    object
#  8   Total Claim Amount         996 non-null    float64
#  9   Policy Type                996 non-null    object
#  10  Vehicle Class              996 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
#Confirming how many NaN are in the Customer Lifetime Value
file2_df['Customer Lifetime Value'].isna().sum()
# Out:
# 4

# %%
#Checking how many '%' are in the column Customer Lifetime Value
count_percent2 = file2_df['Customer Lifetime Value'].str.contains('%').sum()
count_percent2
# Out:
# 992

# %%
#Checking how file 3 looks like
file3_df
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#Checking info and data types of file 3. Number of Open Complaints is an integer as expected \
 #and Customer Lifetime Value is a float as expected.
file3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Customer Lifetime Value    7070 non-null   float64
#  3   Education                  7070 non-null   object
#  4   Gender                     7070 non-null   object
#  5   Income                     7070 non-null   int64
#  6   Monthly Premium Auto       7070 non-null   int64
#  7   Number of Open Complaints  7070 non-null   int64
#  8   Policy Type                7070 non-null   object
#  9   Total Claim Amount         7070 non-null   float64
#  10  Vehicle Class              7070 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
#Confirming the total of NaN in Customer Lifetime Value
file3_df['Customer Lifetime Value'].isna().sum()
# Out:
# 0

# %%
count_percent3 = file3_df['Customer Lifetime Value'].str.contains('%').sum()
count_percent3 
# it gives an error because all the data in Customer Lifetime Value for file 3 are floats, meaning itself that there are no %.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/z4/jwp_0zd9645ffr0g501f512r0000gn/T/ipykernel_21758/2937686765.py in <module>
# ----> 1 count_percent3 = file3_df['Customer Lifetime Value'].str.contains('%').sum()
#       2 count_percent3
#       3 # it gives an error because all the data in Customer Lifetime Value for file 3 are floats, meaning itself that there are no %.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
#creating a function to put all headers in lower case
def lower_case_column_names(file1_df): 
    file1_df.columns=[i.lower() for i in file1_df.columns]
    return file1_df
file1_df=lower_case_column_names(file1_df)
file1_df

#another way to do it using the rename method and a lambda function
## df1 = df1.rename(columns= lambda x: x.lower())
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#Applying fuction lower_case_column_names to file 2 and checking how file 2 looks like again with update
file2_df=lower_case_column_names(file2_df)
file2_df
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
#Applying fuction lower_case_column_names to file 2 and checking how file 2 looks like again with update
file3_df=lower_case_column_names(file3_df)
file3_df
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
# creating a function for homologating headers and changing ' ' for '_' and checking the changes in file
def rename_columns(file1_df): 
    file1_df.rename(columns={'st':'state','customer lifetime value':'customer_lifetime_value',
                          'monthly premium auto':'monthly_premium_auto',"number of open complaints":"number_of_open_complaints", 
                          "policy type":"policy_type","total claim amount": "total_claim_amount",
                          "vehicle class":"vehicle_class"}, inplace=True )
    return file1_df
file1_df=rename_columns(file1_df)
file1_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Applying function of rename_columns and applying to file 2
file2_df=rename_columns(file2_df)
file2_df
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
# Applying function of rename_columns and applying to file 3
file3_df=rename_columns(file3_df)
file3_df
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#concatenating the 3 files into one
file_total_df = pd.concat([file1_df,file2_df,file3_df], axis=0)
file_total_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#checking the info and type of variables of the concatenated df
file_total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer_lifetime_value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly_premium_auto       9137 non-null   float64
#  7   number_of_open_complaints  9137 non-null   object
#  8   policy_type                9137 non-null   object
#  9   vehicle_class              9137 non-null   object
#  10  total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
print(file_total_df['customer_lifetime_value'].isna().sum())
print(file_total_df['gender'].isna().sum())
# there are NaN values in gender and in customer_lifetime_value
# customer_lifetime_value is object type --> needs to be fixed integers or floats
# number_of_open_complaints is object type --> needs to be fixed to integers
# Out:
# 2944
# 3059

# %%
# Eliminating duplicates in the total file
file_total_df=file_total_df.drop_duplicates() 
file_total_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# resetting index after concatenation of 3 files and dropping duplicates
file_total_df = file_total_df.reset_index() 
file_total_df
# Out:
#       index customer       state gender             education  \
# 0         0  RB50392  Washington    NaN                Master
# 1         1  QZ44356     Arizona      F              Bachelor
# 2         2  AI49188      Nevada      F              Bachelor
# 3         3  WW63253  California      M              Bachelor
# 4         4  GA49547  Washington      M  High School or Below
# ...     ...      ...         ...    ...                   ...
# 9130   7065  LA72316  California      M              Bachelor
# 9131   7066  PK87824  California      F               College
# 9132   7067  TD14365  California      M              Bachelor
# 9133   7068  UP19263  California      M               College
# 9134   7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
# creating a function that drops columns index (index of original 3 files) and customer
def drop_columns(file_total_df) :            
    file_total_df.drop(columns=["index","customer"], inplace=True)
    return file_total_df
drop_columns(file_total_df)
file_total_df
# Out:
#            state gender             education customer_lifetime_value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 9130  California      M              Bachelor             23405.98798
# 9131  California      F               College             3096.511217
# 9132  California      M              Bachelor             8163.890428
# 9133  California      M               College             7524.442436
# 9134  California      M               College             2611.836866
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
#checking the total of NaN after dropping duplicates
file_total_df['customer_lifetime_value'].isna().sum()
# Out:
# 8

# %%
#checking how many times there is '%' in the column 'customer_lifetime_value'
count_percent = file_total_df['customer_lifetime_value'].str.contains('%').sum()
count_percent
# Out:
# 2057

# %%
# removing % whiting the customer_lifetime_value
# Define a function to remove '%' from string values
def remove_percent(x):
    if isinstance(x, str):
        return x.strip('%')
    else:
        return x

# Apply the function to the 'customer_lifetime_value' column using .apply()
file_total_df['customer_lifetime_value'] = file_total_df['customer_lifetime_value'].apply(remove_percent)

# %%
# counting the '%' at the customer_lifetime_value after running the function
count_percent_update = file_total_df['customer_lifetime_value'].str.contains('%').sum()
count_percent_update
# Out:
# 0

# %%
# extracting the middle number in the number_of_open_compalints that has the format of x/x/xx
## lambda function lambda x: if ... else x
file_total_df['number_of_open_complaints'] = \
file_total_df['number_of_open_complaints'].apply(lambda x: int(x.split('/')[1]) if '/' in str(x) else x)
file_total_df
# Out:
#            state gender             education customer_lifetime_value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 9130  California      M              Bachelor             23405.98798
# 9131  California      F               College             3096.511217
# 9132  California      M              Bachelor             8163.890428
# 9133  California      M               College             7524.442436
# 9134  California      M               College             2611.836866
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#checking the number NaNs in the customer_lifetime_value column after the merge
file_total_df['customer_lifetime_value'].isna().sum()
# Out:
# 8

# %%
#checking the index NaNs in the customer_lifetime_value column after the merge
file_total_df[file_total_df['customer_lifetime_value'].isnull()].index
# Out:
# Int64Index([0, 78, 988, 1071, 1394, 1441, 1649, 1930], dtype='int64')

# %%
#checking the number NaNs in the number_of_open_complaints column after the merge
file_total_df[file_total_df['number_of_open_complaints'].isnull()].index
# Out:
# Int64Index([1071], dtype='int64')

# %%
#checking the index NaNs in the number_of_open_complaints column after the merge
file_total_df['number_of_open_complaints'].isna().sum()
# Out:
# 1

# %%
# Defining a function that will change the NaN for 0 in order to convert the column into integers in next steps.
def change_NaN(x):
    if pd.isna(x):
        return 0
    else:
        return x
# applying the function to the customer_lifetime_value
file_total_df['customer_lifetime_value'] = file_total_df['customer_lifetime_value'].apply(change_NaN)
file_total_df['customer_lifetime_value'].isna().sum()
# Out:
# 0

# %%
# applying the function to the number_of_open_complaints
file_total_df['number_of_open_complaints'] = file_total_df['number_of_open_complaints'].apply(change_NaN)
file_total_df['number_of_open_complaints'].isna().sum()
# Out:
# 0

# %%
# changing the data type to integers and checking the conversion
file_total_df['number_of_open_complaints'] = file_total_df['number_of_open_complaints'].astype(int)
file_total_df['number_of_open_complaints'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9135 entries, 0 to 9134
# Series name: number_of_open_complaints
# Non-Null Count  Dtype
# --------------  -----
# 9135 non-null   int64
# dtypes: int64(1)
# memory usage: 71.5 KB

# %%
# changing the data type to integers and checking the conversion
file_total_df['customer_lifetime_value'] = pd.to_numeric(file_total_df['customer_lifetime_value'], errors='coerce')
file_total_df['customer_lifetime_value'] = file_total_df['customer_lifetime_value'].fillna(0).astype(int)
file_total_df['customer_lifetime_value'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9135 entries, 0 to 9134
# Series name: customer_lifetime_value
# Non-Null Count  Dtype
# --------------  -----
# 9135 non-null   int64
# dtypes: int64(1)
# memory usage: 71.5 KB

# %%
# checking how the data type look like after changes in customer_lifetime_value and number_of_open_complaints
file_total_df
# Out:
#            state gender             education  customer_lifetime_value  \
# 0     Washington    NaN                Master                        0
# 1        Arizona      F              Bachelor                   697953
# 2         Nevada      F              Bachelor                  1288743
# 3     California      M              Bachelor                   764586
# 4     Washington      M  High School or Below                   536307
# ...          ...    ...                   ...                      ...
# 9130  California      M              Bachelor                    23405
# 9131  California      F               College                     3096
# 9132  California      M              Bachelor                     8163
# 9133  California      M               College                     7524
# 9134  California      M               College                     2611
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#Filtering data and Correcting typos – Filter the data in state and gender column to standardize the \
#texts in those columns
file_total_df['gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
#Homogenizing the 'gender' column but leaving the NaN
gender_updated = {'F':'female','M':'male','Femal':'female','Male':'male','female':'female'}    
file_total_df['gender'] = file_total_df['gender'].replace(gender_updated)

# %%
#checking the new unique values of column 'gender'
file_total_df['gender'].unique()
# Out:
# array([nan, 'female', 'male'], dtype=object)

# %%
file_total_df['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
#Homogenizing the 'state' column but leaving the NaN
state_updated = {'WA':'Washington','Cali':'California','AZ':'Arizona'}    
file_total_df['state'] = file_total_df['state'].replace(state_updated)

# %%
#checking the new unique values of column 'state'
file_total_df['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %% [markdown]
# ## Activity 2 (Tuesday)
#
# - Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values) Hint: numpy.nan is considered of float64 data type.
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
# - (Optional) In the column Vehicle Class, merge the two categories Luxury SUV and Luxury Car into one category named Luxury Vehicle
# - (Optional) Removing outliers using 1.5*IQR technique for all numerical columns.
# - (Optional) Standardizing the data – Use string functions to standardize the text data (lower case)

# %%
#checking again the info and type of variables and the amount of NaN
file_total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9135 entries, 0 to 9134
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9134 non-null   object
#  1   gender                     9012 non-null   object
#  2   education                  9134 non-null   object
#  3   customer_lifetime_value    9135 non-null   int64
#  4   income                     9134 non-null   float64
#  5   monthly_premium_auto       9134 non-null   float64
#  6   number_of_open_complaints  9135 non-null   int64
#  7   policy_type                9134 non-null   object
#  8   vehicle_class              9134 non-null   object
#  9   total_claim_amount         9134 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 713.8+ KB

# %%
#Finding the mean of customer_lifetime
customer_lifetime_nonzero = []
for i in file_total_df['customer_lifetime_value']:
    if i != 0:
        customer_lifetime_nonzero.append(i)

customer_lifetime_mean = sum(customer_lifetime_nonzero)/len(customer_lifetime_nonzero)    
customer_lifetime_mean
# Out:
# 182070.87619047618

# %%
#Replacing the 0 values for the mean  ---> Needs to be changed leaving out the 0 first
file_total_df['customer_lifetime_value'] = \
file_total_df['customer_lifetime_value'].apply(lambda x: customer_lifetime_mean if x == 0 else x)

# %%
#Finding the mean of income
income_nonzero = []
for i in file_total_df['income']:
    if i != 0:
        income_nonzero.append(i)
income_mean = sum(income_nonzero)/len(income_nonzero)  
income_mean
# Out:
# 47323.538916256155

# %%
#Replacing the 0 values for the mean
file_total_df['income'] = \
file_total_df['income'].apply(lambda x: income_mean if x == 0 else x)

# %%
#Replacing the NaN values for the mean
file_total_df['income'] = \
file_total_df['income'].apply(lambda x: income_mean if pd.isna(x) else x)

# %%
#Finding the mean of monthly_premium_auto
monthly_premium_auto_nonzero = []
for i in file_total_df['monthly_premium_auto']:
    if i != 0:
        monthly_premium_auto_nonzero.append(i)

monthly_premium_auto_mean = sum(monthly_premium_auto_nonzero)/len(monthly_premium_auto_nonzero)  
monthly_premium_auto_mean
# Out:
# 110.39310344827587

# %%
#Replacing the 0 values for the mean
file_total_df['monthly_premium_auto'] = \
file_total_df['monthly_premium_auto'].apply(lambda x: monthly_premium_auto_mean if x == 0 else x)

# %%
#Replacing the NaN values for the mean
file_total_df['monthly_premium_auto'] = \
file_total_df['monthly_premium_auto'].apply(lambda x: monthly_premium_auto_mean if pd.isna(x) else x)

# %%
#Finding the mean of number_of_open_complaints
number_of_open_complaints_nonzero = []
for i in file_total_df['number_of_open_complaints']:
    if i != 0:
        number_of_open_complaints_nonzero.append(i)

number_of_open_complaints_mean = sum(number_of_open_complaints_nonzero)/len(number_of_open_complaints_nonzero) 
number_of_open_complaints_mean
#As the mean is 0, there is no need to do replacement. There are also none NaN in this column.
# Out:
# 1.8629117959617427

# %%
#Replacing the NaN values for the mean
file_total_df['number_of_open_complaints'] = \
file_total_df['number_of_open_complaints'].apply(lambda x: monthly_premium_auto_mean if pd.isna(x) else x)

# %%
#Finding the mean of total_claim_amount
total_claim_amount_nonzero = []
for i in file_total_df['total_claim_amount']:
    if i != 0:
        total_claim_amount_nonzero.append(i)

total_claim_amount_mean = sum(total_claim_amount_nonzero)/len(total_claim_amount_nonzero) 
total_claim_amount_mean
# Out:
# 430.4803589275289

# %%
#Replacing the 0 values for the mean
file_total_df['total_claim_amount'] = \
file_total_df['total_claim_amount'].apply(lambda x: total_claim_amount_mean if x == 0 else x)

# %%
#Replacing the NaN values for the mean
file_total_df['total_claim_amount'] = \
file_total_df['total_claim_amount'].apply(lambda x: total_claim_amount_mean if pd.isna(x) else x)

# %%
#Checking that the changes were in place
file_total_df
# Out:
#                state  gender             education  customer_lifetime_value  \
# 0        East Region     NaN                Master                   181912
# 1     Central Region  female              Bachelor                   697953
# 2     Central Region  female              Bachelor                  1288743
# 3        West Region    male              Bachelor                   764586
# 4        East Region    male  High School or Below                   536307
# ...              ...     ...                   ...                      ...
# 9130     West Region    male              Bachelor                    23405
# 9131     West Region  female               College                     3096
# 9132     West Region    male              Bachelor                     8163
# 9133     West Region    male               College                     7524
# 9134     West Region    male               College                     2611
#
# ...

# %%
#checking that there are non NaN for the numeric variables
file_total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9135 entries, 0 to 9134
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9134 non-null   object
#  1   gender                     9012 non-null   object
#  2   education                  9134 non-null   object
#  3   customer_lifetime_value    9135 non-null   int64
#  4   income                     9135 non-null   float64
#  5   monthly_premium_auto       9135 non-null   float64
#  6   number_of_open_complaints  9135 non-null   int64
#  7   policy_type                9134 non-null   object
#  8   vehicle_class              9134 non-null   object
#  9   total_claim_amount         9135 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 713.8+ KB

# %%
#Defining a function to change state for region: California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
def region (x):
    file_total_df['state'] = file_total_df['state'].replace({'California':'West Region','Oregon':'North West Region',
                          'Washington':'East Region',"Arizona":"Central Region", 
                          "Nevada":"Central Region"})
    return file_total_df
file_total_df=region(file_total_df)

# %%
#Checking that the changes in region were in place
file_total_df
# Out:
#                state  gender             education  customer_lifetime_value  \
# 0        East Region     NaN                Master                   181912
# 1     Central Region  female              Bachelor                   697953
# 2     Central Region  female              Bachelor                  1288743
# 3        West Region    male              Bachelor                   764586
# 4        East Region    male  High School or Below                   536307
# ...              ...     ...                   ...                      ...
# 9130     West Region    male              Bachelor                    23405
# 9131     West Region  female               College                     3096
# 9132     West Region    male              Bachelor                     8163
# 9133     West Region    male               College                     7524
# 9134     West Region    male               College                     2611
#
# ...
