# %% [markdown]
# # <span style='color:green'> Hello! Meet Angelica </span>

# %% [markdown]
# **The purpose of this notebook is to introduce myself, Angelica Blanco, and my preferences for holidays.**

# %%
# This function is for the user to insert the name of the person that is going to be introduced.
name = input ('Please introduce the name of the person to be introduced: ')
# Out:
# Please introduce the name of the person to be introduced: Angelica

# %% [markdown]
# ![Angelica-%20retrato-%20Maria%20Rapela%20Foto%20-%20formato%20social%20media-72dpi-.jpg](attachment:Angelica-%20retrato-%20Maria%20Rapela%20Foto%20-%20formato%20social%20media-72dpi-.jpg)

# %% [markdown]
# ## <span style='color:Blue'> My holiday destination is: </span>

# %% [markdown]
# ![Portugal_Static_Map.png](attachment:Portugal_Static_Map.png)

# %% [markdown]
# - I would like to got Nazaré, to see the world's biggest, gnarliest waves

# %% [markdown]
# ![7158.jpg.webp](attachment:7158.jpg.webp)

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/GJc4Ir78KdE"
# </iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/GJc4Ir78KdE"
# </iframe>

# %% [markdown]
# - I want to get to know the best beaches in Portugal, and swimm there

# %% [markdown]
# ![portugal-praia-do-camilo-1.jpeg](attachment:portugal-praia-do-camilo-1.jpeg)

# %% [markdown]
# - I want to eat the delicious sea food they have

# %% [markdown]
# ![Seafood-platters.jpg.webp](attachment:Seafood-platters.jpg.webp)
